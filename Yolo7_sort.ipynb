# %% [markdown]
# <a href="https://colab.research.google.com/github/Ketheesram/Network-Diagram/blob/main/Yolo7_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed May  3 10:27:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
Home=os.getcwd()
print(Home)
# Out:
# /content

# %%
# !git clone https://github.com/haroonshakeel/yolov7-object-tracking.git
# Out:
# Cloning into 'yolov7-object-tracking'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 26 (delta 4), reused 3 (delta 3), pack-reused 21
# Unpacking objects: 100% (26/26), 6.67 MiB | 3.39 MiB/s, done.

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1139, done.
# remote: Total 1139 (delta 0), reused 0 (delta 0), pack-reused 1139
# Receiving objects: 100% (1139/1139), 70.41 MiB | 12.80 MiB/s, done.
# Resolving deltas: 100% (486/486), done.

# %%
# %cd /content/yolov7-object-tracking
# Out:
# /content/yolov7-object-tracking

# %%
# !mv requirements.txt /content/yolov7
# !mv sort.py /content/yolov7
# !mv street.mp4 /content/yolov7
# !mv detect_or_track.py /content/yolov7
# !mv requirements_gpu.txt /content/yolov7

# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %%
# !pip install -r requirements.txt

# %%
# !pip install -r requirements_gpu.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu113
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 GB 886.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 43.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.11.0+cu113 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.11.0+cu113 which is incompatible.
# ...

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python detect_or_track.py --weight yolov7x.pt --no-trace  --project ketheesh  --source MOTChallenge.mp4 --track
# Out:
# Namespace(weights=['yolov7x.pt'], source='MOTChallenge.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='ketheesh', name='exp', exist_ok=False, no_trace=True, track=True, show_track=False, show_fps=False, thickness=2, seed=1, nobbox=False, nolabel=False, unique_track_color=False)
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.11.0+cu113 CPU
#
# Fusing layers...
# Model Summary: 354 layers, 71311741 parameters, 571965 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
